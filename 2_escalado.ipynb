# %% [markdown]
# # Escalado
# Conjunto de datos: iris (incluido en sklearn)
# Este conjunto de datos es compacto y perfecto para demostrar técnicas de escalado.

# %%
# Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
iris = load_iris(as_frame=True)
data = iris.data

# %%
# Visualizar las estadísticas iniciales
print("Estadísticas iniciales:")
data.describe()
# Out:
# Estadísticas iniciales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Aplicar MinMaxScaler
minmax_scaler = MinMaxScaler()
data_minmax = pd.DataFrame(minmax_scaler.fit_transform(data), columns=data.columns)

# %%
# Aplicar StandardScaler
standard_scaler = StandardScaler()
data_standard = pd.DataFrame(standard_scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado. Crea gráficas en donde veas correcto.

# %% [markdown]
# ### 1. ¿Qué diferencias encuentras entre las estadísticas originales y las del escalado MinMax?

# %%
print("Estadísticas originales:")
print(data.describe())

print("\nEstadísticas tras MinMaxScaler:")
print(data_minmax.describe())

# La principal diferencia es que todas las columnas escaladas tienen valores en el rango [0, 1].
# Esto se observa en min=0.0 y max=1.0 para cada columna tras el escalado.
# Out:
# Estadísticas originales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Estadísticas tras MinMaxScaler:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...

# %% [markdown]
# ### 2. Crea una gráfica de la distribución de la variable 'sepal length (cm)' antes y después del escalado.

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['sepal length (cm)'], bins=15, alpha=0.6, label='Original', color='blue')
plt.hist(data_minmax['sepal length (cm)'], bins=15, alpha=0.6, label='MinMax escalado', color='orange')
plt.title('Distribución de sepal length (cm) antes y después del escalado')
plt.xlabel('sepal length (cm)')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# ### 3. Crea una gráfica de dispersión entre 'sepal length (cm)' y 'sepal width (cm)' con los datos escalados por StandardScaler.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_standard['sepal length (cm)'], data_standard['sepal width (cm)'], alpha=0.7, edgecolor='k')
plt.title('Dispersión de sepal length vs sepal width (StandardScaler)')
plt.xlabel('sepal length (cm) [StandardScaler]')
plt.ylabel('sepal width (cm) [StandardScaler]')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. ¿Qué técnica de escalado crees que es más adecuada para este conjunto de datos? ¿Por qué?

# %%
print("Para este conjunto de datos iris, StandardScaler suele ser más adecuado porque preserva la forma de la distribución")
print("y centra los datos en media 0 con desviación estándar 1, lo que es útil para algoritmos que dependen de la varianza.")
print("MinMaxScaler también es válido cuando se necesita un rango específico [0,1], pero StandardScaler es más robusto frente a valores extremos.")
# Out:
# Para este conjunto de datos iris, StandardScaler suele ser más adecuado porque preserva la forma de la distribución
# y centra los datos en media 0 con desviación estándar 1, lo que es útil para algoritmos que dependen de la varianza.
# MinMaxScaler también es válido cuando se necesita un rango específico [0,1], pero StandardScaler es más robusto frente a valores extremos.
